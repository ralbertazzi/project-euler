# %% [markdown]
# # Problem 39
#
# If p is the perimeter of a right angle triangle with integral length
# sides, {a,b,c}, there are exactly three solutions for p = 120.
#
# {20,48,52}, {24,45,51}, {30,40,50}
#
# For which value of p ≤ 1000, is the number of solutions maximised?

# %% [markdown]
# ### Solution
#
# Use an array of counters to store how many times we found a solution for that *p*.
# Also compute some square to square root conversions inside the interval of integers required.

# %%
import numpy as np

counts = np.zeros(1001, dtype=np.int)
squares = {n**2: n for n in xrange(1000)}

# %% [markdown]
# If *p* is the perimeter, and *c* the hypotenus, then *a* and *b* will be surely less then *p/2*.
# When iterating over *a* and *b*, if we find a squared hypotenuse with square root and the triple of numbers has a perimeter lte 1000, then we have a solution.

# %%
for a in xrange(1, 500):
    for b in xrange(a, 500):
        
        c_squared = a**2 + b**2
        if c_squared in squares:
            c = squares[c_squared]
            
            p = a + b + c
            if p <= 1000:
                print (a, b, c)
                counts[p] += 1
# Out:
# (3, 4, 5)
# (5, 12, 13)
# (6, 8, 10)
# (7, 24, 25)
# (8, 15, 17)
# (9, 12, 15)
# (9, 40, 41)
# (10, 24, 26)
# (11, 60, 61)
# (12, 16, 20)
# (12, 35, 37)
# (13, 84, 85)
# (14, 48, 50)
# (15, 20, 25)
# (15, 36, 39)
# (15, 112, 113)
# (16, 30, 34)
# (16, 63, 65)
# (17, 144, 145)
# (18, 24, 30)
# (18, 80, 82)
# (19, 180, 181)
# (20, 21, 29)
# (20, 48, 52)
# (20, 99, 101)
# (21, 28, 35)
# (21, 72, 75)
# (21, 220, 221)
# (22, 120, 122)
# (23, 264, 265)
# (24, 32, 40)
# (24, 45, 51)
# (24, 70, 74)
# (24, 143, 145)
# (25, 60, 65)
# (25, 312, 313)
# (26, 168, 170)
# (27, 36, 45)
# (27, 120, 123)
# (27, 364, 365)
# (28, 45, 53)
# (28, 96, 100)
# (28, 195, 197)
# (29, 420, 421)
# (30, 40, 50)
# (30, 72, 78)
# (30, 224, 226)
# (31, 480, 481)
# (32, 60, 68)
# (32, 126, 130)
# (32, 255, 257)
# (33, 44, 55)
# (33, 56, 65)
# (33, 180, 183)
# (34, 288, 290)
# (35, 84, 91)
# (35, 120, 125)
# (36, 48, 60)
# (36, 77, 85)
# (36, 105, 111)
# (36, 160, 164)
# (36, 323, 325)
# (38, 360, 362)
# (39, 52, 65)
# ...

# %% [markdown]
# Print the *p* with the most solutions, and (optional) the number of the solutions

# %%
best_p = np.argmax(counts)

print best_p, counts[best_p]
# Out:
# 840 8
